# %% [markdown]
# I chose to create a database of all the events booked within a year at an event venue in Minneapolis, "Xcel Energy Center". This venue is home to the Minnesota Wild in addition to a music venue for large acts and such.

# %% [markdown]
# Disclaimer: I initially started doing this as separate functions but later found out a flaw in ThreadPoolExecutor in that it essentially randomizes the order in list outputs, and if you're trying to combine things that rely on a sequential order, this will prove useless.
#
# As such, I ended up combining everything in one function. But I chose to leave this notebook as a procession of my progress rather than cleaning it up so it only has the final function. So the final function is near the bottom.

# %%
import pandas as pd
import re
from concurrent.futures import ThreadPoolExecutor

# %%
# Our jupyter/datascience-notebook Docker container comes with 
# BeautifulSoup4 and requests, both popular libraries!

from bs4 import BeautifulSoup
import requests

# %%
START_URL = 'https://www.xcelenergycenter.com/events/all'

# %%
response = requests.get(START_URL)
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# # From the initial webpage, get the "More Info" URL present next to each event.

# %%
# %%time
##6.9 ms -- no need for distributing workloads 

all_urls = soup.select('#list > div > div.thumb > div > a')

all_urls_list = []

for i in range(0, len(all_urls)):
    all_urls_list.append(all_urls[i]['href'])    

##this includes both the ticket pages and the "more info" pages, but if a show is cancelled
##they will just remove the link to purchase tickets and then the list becomes out of order
##but the "more info" button is always there! so sub out those ones:
    
substring = 'xcelenergycenter'

more_info_url_list = []

for i in range(0, len(all_urls_list)):
    if substring in all_urls_list[i]:
        more_info_url_list.append(all_urls_list[i])    

print(more_info_url_list)

##make it a column
pdmore_info_url_list = pd.DataFrame(more_info_url_list)
# Out:
# ['https://www.xcelenergycenter.com/events/detail/mshsl-girls-volleyball-tournament-5', 'https://www.xcelenergycenter.com/events/detail/drake-1', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-washington-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-vancouver-3', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-buffalo-1', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-ottawa-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-winnipeg-8', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-arizona-4', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-toronto-1', 'https://www.xcelenergycenter.com/events/detail/1013-kdwbs-jingle-ball-presented-by-capital-one', 'https://www.xcelenergycenter.com/events/detail/disney-on-ice-celebrates-100-years-of-magic', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-montreal-2', 'https://www.xcelenergycenter.com/events/detail/postponed-bob-seger-the-silver-bullet-band', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-florida-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-calgary-2', 'https://www.xcelenergycenter.com/events/detail/wild-about-children', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-san-jose-3', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-dallas-5', 'https://www.xcelenergycenter.com/events/detail/trans-siberian-orchestra-4', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-pittsburgh-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-winnipeg-9', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-detroit-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-los-angeles-3', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-anaheim-3', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-columbus-2', 'https://www.xcelenergycenter.com/events/detail/cinch-worlds-toughest-rodeo-1', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-chicago-5', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-edmonton-3', 'https://www.xcelenergycenter.com/events/detail/trevor-noah-loud-and-clear-tour', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-philadelphia-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-new-jersey-2', 'https://www.xcelenergycenter.com/events/detail/kelly-clarkson-1', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-st-louis-8', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-anaheim-4', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-st-louis-9', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-nashville-5', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-san-jose-4', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-dallas-6', 'https://www.xcelenergycenter.com/events/detail/blake-shelton-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-ny-rangers-2', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-new-york-islanders', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-colorado-9', 'https://www.xcelenergycenter.com/events/detail/nchc-frozen-faceoff-1', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-nashville-6', 'https://www.xcelenergycenter.com/events/detail/weezer-and-pixies', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-winnipeg-10', 'https://www.xcelenergycenter.com/events/detail/minnesota-wild-vs-boston-1', 'https://www.xcelenergycenter.com/events/detail/ariana-grande-2', 'https://www.xcelenergycenter.com/events/detail/pnk-2', 'https://www.xcelenergycenter.com/events/detail/cher', 'https://www.xcelenergycenter.com/events/detail/new-kids-on-the-block-2', 'https://www.xcelenergycenter.com/events/ ...
# CPU times: user 7.89 ms, sys: 637 µs, total: 8.53 ms
# Wall time: 8.32 ms

# %% [markdown]
# # Now, create separate functions to get each of the elements from the page that you would like from each URL.

# %%
# %%time
##23 µs -- no need for distributing workloads 

titlez_list = []

def get_titles(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the title from the pages
    titlez = newsoup.select('#content > div.event_detail.one_sidebar_right.has_branding > div.title_section.clearfix > div.event_heading.below_branding > h1')    
    titlez_list.append(titlez[0].text[3:-1])
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs

# %% [markdown]
# ### Use the thread pool functions to distribute the workload.

# %%
# %%time
titlez_list = []

with ThreadPoolExecutor(50) as pool:
       resultstitles = pool.map(get_titles, more_info_url_list)
        
print(titlez_list)
# Out:
# ['Minnesota Wild vs. Arizona', 'Disney On Ice', 'Drake - cancelled', "MSHSL Girls' State Volleyball Tournament", 'Minnesota Wild vs. Anaheim', 'Minnesota Wild vs. Dallas', 'Minnesota Wild vs. Winnipeg', 'Minnesota Wild vs. Anaheim', 'Wild About Children', 'Minnesota Wild vs. Chicago', 'Minnesota Wild vs. New York Rangers', 'Minnesota Wild vs. Los Angeles', "101.3 KDWB's Jingle Ball", 'NCHC Frozen Faceoff', 'Minnesota Wild vs. Montreal', 'Minnesota Wild vs. Philadelphia', 'Blake Shelton', 'Minnesota Wild vs. St. Louis', 'Minnesota Wild vs. Washington', 'Minnesota Wild vs. Columbus', 'Minnesota Wild vs. St. Louis', 'Minnesota Wild vs. Dallas', 'Cher', 'Minnesota Wild vs. San Jose', 'Trans-Siberian Orchestra', 'Minnesota Wild vs. Vancouver', 'Minnesota Wild vs. Edmonton', 'Kelly Clarkson', 'P!NK', 'Minnesota Wild vs. Winnipeg', 'Minnesota Wild vs. Detroit', 'Minnesota Wild vs. Colorado', 'Trevor Noah: Loud & Clear Tour', 'Minnesota Wild vs. Boston', 'Minnesota Wild vs. Buffalo', 'Minnesota Wild vs. Nashville', 'Minnesota Wild vs. New Jersey', 'Weezer and Pixies', 'Minnesota Wild vs. Florida', 'Ariana Grande', 'Minnesota Wild vs. San Jose', 'Minnesota Wild vs. New York Islanders', 'Minnesota Wild vs. Calgary', 'Minnesota Wild vs. Toronto', 'Shawn Mendes', 'Minnesota Wild vs. Nashville', 'Bob Seger & The Silver Bullet Band', "Cinch World's Toughest Rodeo", 'Minnesota Wild vs. Pittsburgh', 'Minnesota Wild vs. Winnipeg', 'Minnesota Wild vs. Ottawa', 'New Kids On The Block', 'Ozzy Osbourne', "Jeff Lynne's ELO LIVE 2019"]
# CPU times: user 2.98 s, sys: 281 ms, total: 3.26 s
# Wall time: 4.4 s

# %%
# %%time
##23 µs -- no need for distributing workloads 

month_list = []

def get_months(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the month from the pages
    months = newsoup.select('span > span > span.m-date__month')    
    month_list.append(months[0].text)
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs

# %%
# %%time
month_list = []

with ThreadPoolExecutor(50) as pool:
       resultsmon = pool.map(get_months, more_info_url_list)
        
print(month_list)
# Out:
# ['Dec ', 'Dec ', 'Nov ', 'Dec ', 'Nov ', 'Dec ', 'Dec ', 'Nov ', 'Nov ', 'Dec ', 'Dec ', 'Nov ', 'Dec ', 'Nov ', 'Jan ', 'Nov ', 'Dec ', 'Nov ', 'Feb ', 'Jan ', 'Jan ', 'Feb ', 'Feb ', 'Dec ', 'Dec ', 'Feb ', 'Feb ', 'Jan ', 'Apr ', 'Mar ', 'Mar ', 'Feb ', 'Mar ', 'Jan ', 'Mar ', 'Mar ', 'Jan ', 'Dec ', 'Mar ', 'Feb ', 'Mar ', 'Feb ', 'Feb ', 'Apr ', 'Apr ', 'Mar ', 'Mar ', 'July ', 'May ', 'June ', 'June ', 'May ', 'Mar ', 'July ']
# CPU times: user 3.26 s, sys: 627 ms, total: 3.88 s
# Wall time: 2.7 s

# %%
# %%time
##23 µs -- no need for distributing workloads 

weekday_list = []

def get_weekdays(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the weekday from the pages
    weekday = newsoup.select('span > span > span.m-date__weekday')
    
    weekday_list.append(weekday[0].text[:3])
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.72 µs

# %%
# %%time

weekday_list = []

## this is 16 times faster with thread pool
with ThreadPoolExecutor(50) as pool:
       resultsWEEKDAY = pool.map(get_weekdays, more_info_url_list)
        
print(weekday_list)
# Out:
# ['Thu', 'Thu', 'Wed', 'Tue', 'Sat', 'Wed', 'Tue', 'Sun', 'Sat', 'Thu', 'Fri', 'Sat', 'Tue', 'Thu', 'Mon', 'Sat', 'Sat', 'Thu', 'Tue', 'Sat', 'Thu', 'Sat', 'Tue', 'Fri', 'Mon', 'Thu', 'Sun', 'Fri', 'Mon', 'Sat', 'Sun', 'Sat', 'Sun', 'Sun', 'Tue', 'Sat', 'Sat', 'Fri', 'Sun', 'Tue', 'Tue', 'Tue', 'Fri', 'Sat', 'Sat', 'Sun', 'Tue', 'Mon', 'Thu', 'Thu', 'Wed', 'Sat', 'Thu', 'Fri']
# CPU times: user 3.14 s, sys: 372 ms, total: 3.51 s
# Wall time: 2.68 s

# %%
# %%time
##22 µs -- no need for distributing workloads 

numday_list = []

def get_numdays(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the day of the month from the pages
    numday = newsoup.select('span > span > span.m-date__day')
    
    numday_list.append(numday[0].text)
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
# %%time

numday_list = []

## this is 17 times faster with the thread pool
with ThreadPoolExecutor(50) as pool:
       resultsNUM = pool.map(get_numdays, more_info_url_list)
        
print(numday_list)
# Out:
# ['29', '12', '18', ' 8', '21', ' 9', '15', '11', ' 3', ' 6', '13', '27', '15', '16', ' 7', '25', ' 1', '15', '19', '18', '15', '17', '14', '13', '22', '19', '31', '10', '12', '25', ' 4', '11', ' 3', '24', '21', '22', '30', ' 5', '16', '17', '17', '12', '23', '16', ' 2', '15', '11', '19', '11', ' 2', '17', '17', ' 6', '25']
# CPU times: user 3.23 s, sys: 535 ms, total: 3.76 s
# Wall time: 2.77 s

# %%
# %%time
##22 µs -- no need for distributing workloads 

year_list = []

def get_year(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the year of the month from the pages
    year = newsoup.select('#column_1 > div > aside > div > div > div.details > ul > li > span > span > span.m-date__year')
    
    year_list.append(year[0].text[-4:])
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
# %%time

year_list = []

## this is 17 times faster with the thread pool
with ThreadPoolExecutor(50) as pool:
       resultsNUM = pool.map(get_year, more_info_url_list)
        
print(year_list)
# Out:
# ['2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2019', '2019', '2018', '2019', '2018', '2018', '2019', '2018', '2018', '2018', '2018', '2018', '2019', '2019', '2018', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019']
# CPU times: user 3.15 s, sys: 497 ms, total: 3.65 s
# Wall time: 2.64 s

# %%
# %%time

buy_tix_url_list = []
##10 µs -- no need for distributing workloads 

def get_buy_tix_url(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the url to buy tickets from the pages
    buy_tix_url = newsoup.select('#column_1 > div > aside > div > div > div.buttonWrapper > div > a')
    
    if buy_tix_url == []:
        buy_tix_url_list.append("This event is cancelled.")
    else:
        buy_tix_url_list.append(buy_tix_url[0]['href'])
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
# %%time

buy_tix_url_list = []

## this is literally 16 times faster than without the thread pool
with ThreadPoolExecutor(50) as pool:
       results = pool.map(get_buy_tix_url, more_info_url_list)
        
print(buy_tix_url_list)
# Out:
# ['https://www.ticketmaster.com/venueartist/49594/1901045?brand=xcelenergy&camefrom=CFC_XCEL_WEB_MSHSLVOLLEYBALL_NOV2018', 'This event is cancelled.', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/venueartist/49594/780815?brand=xcelenergy&camefrom=CFC_XCEL_WEB_TSO_122918', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005533CC98AD09?brand=xcelenergy&camefrom=CFC_XCEL_WEB_JINGLEBALL_120318', 'https://www.nhl.com/wild/community/wild-about-children', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005327E71275E5?brand=xcelenergy&camefrom=CFC_XCEL_WEB_BOBSEGER_121218', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.ticketmaster.com/venueartist/49594/830558?brand=xcelenergy&camefrom=CFC_XCEL_WEB_DOI_2018', 'http://www.ticketmaster.com/venueartist/49594/804555?brand=xcelenergy&camefrom=CFC_XCEL_WEB_RODEO_JAN2018', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005526F7F9336F?brand=xcelenergy&camefrom=CFC_XCEL_WEB_KELLYCLARKSON_021619', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.ticketmaster.com/event/0600554B1C7F3EA8?brand=xcelenergy&camefrom=CFC_XCEL_WEB_TREVORNOAH_020919', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005524DF3AB491?brand=xcelenergy&camefrom=CFC_XCEL_WEB_CHER_051819', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018- ...
# CPU times: user 3.16 s, sys: 507 ms, total: 3.66 s
# Wall time: 2.73 s

# %%
# %%time
##22 µs -- no need for distributing workloads 

time_list = []

def get_the_time(url): 
    
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    #grabs the starting time from the pages
    time = newsoup.select("span.time.cell")
    
    if time == []:
        time_list.append("NA")
    else:
        string = (time[0].text)
        time_list.append(re.findall(r'\d+', string))
    
    ##We don't actually want to return anything because we will be mapping this function
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs

# %%
# %%time

time_list = []

## this is 12.5 times faster than without the thread pool
with ThreadPoolExecutor(50) as pool:
       results = pool.map(get_the_time, more_info_url_list)
        
print(time_list)
# Out:
# [['3', '00'], ['7', '00'], ['6', '30'], ['7', '00'], ['7', '30'], ['5', '00'], ['7', '00'], ['5', '00'], ['7', '00'], ['2', '00'], ['7', '00'], ['7', '00'], ['7', '30'], ['7', '00'], ['7', '00'], ['7', '00'], ['7', '00'], ['7', '00'], ['7', '00'], ['8', '00'], ['7', '00'], ['7', '00'], ['7', '00'], ['12', '30'], ['7', '00'], ['3', '00'], ['7', '00'], ['6', '00'], ['7', '30'], ['7', '00'], ['8', '00'], ['4', '00'], ['7', '00'], ['7', '00'], ['9', '00'], ['7', '00'], ['7', '00'], 'NA', ['7', '00'], ['5', '30'], ['7', '30'], ['6', '00'], ['7', '30'], ['5', '00'], ['7', '30'], ['7', '00'], ['7', '30'], ['7', '00'], ['7', '00'], ['7', '30'], ['7', '30'], ['7', '00'], ['8', '00'], ['8', '00']]
# CPU times: user 3.15 s, sys: 672 ms, total: 3.82 s
# Wall time: 4.42 s

# %%
# %%time
##80 µs -- no need for distributing workloads 

hour = [item[0] for item in time_list]
min = [item[1] for item in time_list]
full_time_list = []

for i in range(0, len(hour)):
    full_time_list.append(hour[i] + ":" + min[i])
# Out:
# CPU times: user 45 µs, sys: 1e+03 ns, total: 46 µs
# Wall time: 48.9 µs

# %% [markdown]
# ## Turn the initial "More Info URL" list into a pandas data frame to concatenate after.

# %%
more_info_url_pd = pd.DataFrame(more_info_url_list)

more_info_url_pd.columns = ["More Info URL"]

# %% [markdown]
# # I have discovered a major flaw in threadpooling -- it does not allow things to be done in an order. So now instead I will put all of this in one function in order to combat the randomization.

# %%
##First ensure all these lists are empty and/or give an easy way to clear them.

weekday_list = []
numday_list = []
month_list = []
year_list = []
time_list = []
titlez_list = []
buy_tix_url_list = []

# %%
weekday_list = []
numday_list = []
month_list = []
year_list = []
time_list = []
titlez_list = []
buy_tix_url_list = []


def grab_every_thang(url): 
  
    ##creates a soup item for each url starting with the starting url (given)
    newresponse = requests.get(url)
    newsoup = BeautifulSoup(newresponse.text, 'html.parser')
    
    
    #grabs the weekday from the pages
    weekday = newsoup.select('span > span > span.m-date__weekday')
    
    weekday_list.append(weekday[0].text[:3])
    
    
    #grabs the day of the month from the pages
    numday = newsoup.select('span > span > span.m-date__day')
    
    numday_list.append(numday[0].text)
    
    
    #grabs the month from the pages    
    months = newsoup.select('span > span > span.m-date__month')    
    month_list.append(months[0].text)
    
    
    #grabs the year of the month from the pages
    year = newsoup.select('#column_1 > div > aside > div > div > div.details > ul > li > span > span > span.m-date__year')
    
    year_list.append(year[0].text[-4:])
    
    
    #grabs the starting time from the pages
    time = newsoup.select("span.time.cell")
    
    if time == []:
        time_list.append("NA")
    else:
        string = (time[0].text)
        time_list.append(re.findall(r'\d+', string))
        
    
    #grabs the title from the pages
    titlez = newsoup.select('#content > div.event_detail.one_sidebar_right.has_branding > div.title_section.clearfix > div.event_heading.below_branding > h1')    
    titlez_list.append(titlez[0].text[3:-1])
    
    
    #grabs the url to buy tickets from the pages
    buy_tix_url = newsoup.select('#column_1 > div > aside > div > div > div.buttonWrapper > div > a')
    
    if buy_tix_url == []:
        buy_tix_url_list.append("This event is cancelled.")
    else:
        buy_tix_url_list.append(buy_tix_url[0]['href'])

# %% [markdown]
# ### Now in theory they thread pools should run in an order such that each list will be created in the same random order, as long as there aren't too many pools.

# %%
weekday_list = []
numday_list = []
month_list = []
year_list = []
time_list = []
titlez_list = []
buy_tix_url_list = []

## this is a calculated number of pools so the final df isn't out of order
## takes about 10 seconds rather than 1 min 30
with ThreadPoolExecutor(10) as pool:
       resultados = pool.map(grab_every_thang, more_info_url_list)

# %%
##Ensure every list was completed

print(len(weekday_list))
print(len(numday_list))
print(len(month_list))
print(len(year_list))
print(len(time_list))
print(len(titlez_list))
print(len(buy_tix_url_list))
# Out:
# 54
# 54
# 54
# 54
# 54
# 54
# 54

# %%
print(weekday_list)
print(numday_list)
print(month_list)
print(year_list)
print(time_list)
print(titlez_list)
print(buy_tix_url_list)
# Out:
# ['Fri', 'Mon', 'Thu', 'Wed', 'Sat', 'Sun', 'Sat', 'Tue', 'Tue', 'Thu', 'Thu', 'Sun', 'Thu', 'Tue', 'Wed', 'Mon', 'Tue', 'Sat', 'Sat', 'Sat', 'Thu', 'Tue', 'Sat', 'Sat', 'Sat', 'Thu', 'Sat', 'Fri', 'Tue', 'Thu', 'Fri', 'Tue', 'Fri', 'Sun', 'Sat', 'Sun', 'Sat', 'Sun', 'Thu', 'Mon', 'Sun', 'Mon', 'Tue', 'Fri', 'Sat', 'Tue', 'Wed', 'Thu', 'Sun', 'Sat', 'Tue', 'Fri', 'Sat', 'Thu']
Wild vs. New York Rangers', 'Minnesota Wild vs. St. Louis', 'Kelly Clarkson', 'Minnesota Wild vs. Nashville', 'Minnesota Wild vs. Dallas', 'Minnesota Wild vs. San Jose', 'Minnesota Wild vs. New York Islanders', 'Minnesota Wild vs. Nashville', 'Minnesota Wild vs. Colorado', 'NCHC Frozen Faceoff', 'Weezer and Pixies', 'Minnesota Wild vs. Winnipeg', 'Ariana Grande', 'Minnesota Wild vs. Boston', 'P!NK', 'Cher', 'New Kids On The Block', 'Shawn Mendes', 'Ozzy Osbourne', "Jeff Lynne's ELO LIVE 2019"]
# ['http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005533CC98AD09?brand=xcelenergy&camefrom=CFC_XCEL_WEB_JINGLEBALL_120318', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'This event is cancelled.', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.ticketmaster.com/venueartist/49594/1901045?brand=xcelenergy&camefrom=CFC_XCEL_WEB_MSHSLVOLLEYBALL_NOV2018', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.nhl.com/wild/community/wild-about-children', 'https://www.ticketmaster.com/venueartist/49594/830558?brand=xcelenergy&camefrom=CFC_XCEL_WEB_DOI_2018', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/event/06005327E71275E5?brand=xcelenergy&camefrom=CFC_XCEL_WEB_BOBSEGER_121218', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/venueartist/49594/780815?brand=xcelenergy&camefrom=CFC_XCEL_WEB_TSO_122918', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.ticketmaster.com/event/0600554B1C7F3EA8?brand=xcelenergy&camefrom=CFC_XCEL_WEB_TREVORNOAH_020919', 'http://www.ticketmaster.com/venueartist/49594/804555?brand=xcelenergy&camefrom=CFC_XCEL_WEB_RODEO_JAN2018', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'https://www.ticketmaster.com/event/06005559AA0B826E?brand=xcelenergy&camefrom=CFC_XCEL_WEB_BLAKESHELTON_031519', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XCEL_WEB_WILD_2018-2019', 'http://www.ticketmaster.com/minnesota-wild-tickets/artist/805974?brand=xcelenergy&camefrom=CFC_XC ...

# %%
##fix the time list
hour = [item[0] for item in time_list]
min = [item[1] for item in time_list]
full_time_list = []

for i in range(0, len(hour)):
    full_time_list.append(hour[i] + ":" + min[i])

# %%
##make month a number for later sorting purposes

for i in range(0, len(month_list)):
    if month_list[i] == "Jan ":
        month_list[i] = 1
    elif month_list[i] == "Feb ":
        month_list[i] = 2
    elif month_list[i] == "Mar ":
        month_list[i] = 3
    elif month_list[i] == "Apr ":
        month_list[i] = 4
    elif month_list[i] == "May ":
        month_list[i] = 5
    elif month_list[i] == "June ":
        month_list[i] = 6
    elif month_list[i] == "July ":
        month_list[i] = 7
    elif month_list[i] == "Aug ":
        month_list[i] = 8
    elif month_list[i] == "Sep ":
        month_list[i] = 9
    elif month_list[i] == "Oct ":
        month_list[i] = 10
    elif month_list[i] == "Nov ":
        month_list[i] = 11
    else:
        month_list[i] = 12

print(month_list)
# Out:
# [11, 12, 11, 11, 12, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 1, 1, 2, 1, 1, 1, 2, 1, 2, 2, 2, 2, 3, 2, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 4, 5, 5, 6, 6, 7, 7]

# %%
##make them a columns in pandas DF form
weekday_list = pd.DataFrame(weekday_list)
numday_list = pd.DataFrame(numday_list)
month_list = pd.DataFrame(month_list)
year_list = pd.DataFrame(year_list)
full_time_list = pd.DataFrame(full_time_list)
titlez_list = pd.DataFrame(titlez_list)
buy_tix_url_list = pd.DataFrame(buy_tix_url_list)

# %%
##Create the initial DF

Initial_DF = pd.concat([weekday_list,
                     numday_list,
                     month_list,
                     year_list,
                     full_time_list,
                     titlez_list, 
                     buy_tix_url_list],
                     axis = 1, ignore_index=True)
Initial_DF.columns = ["Week Day",
                   "Day",
                   "Month",
                    "Year",
                   "Time",
                   "Event", 
                   "Buy Tickets URL"]
Initial_DF
# Out:
#    Week Day Day  Month  Year   Time                                     Event  \
# 0       Fri  23     11  2018   3:00               Minnesota Wild vs. Winnipeg
# 1       Mon   3     12  2018   7:30                  101.3 KDWB's Jingle Ball
# 2       Thu  15     11  2018   7:00              Minnesota Wild vs. Vancouver
# 3       Wed  21     11  2018   7:00                 Minnesota Wild vs. Ottawa
# 4       Sat   1     12  2018   6:00                Minnesota Wild vs. Toronto
# 5       Sun  11     11  2018    N:A                         Drake - cancelled
# 6       Sat  17     11  2018   5:00                Minnesota Wild vs. Buffalo
# 7       Tue  13     11  2018   7:00             Minnesota Wild vs. Washington
# 8       Tue  27     11  2018   7:00                Minnesota Wild vs. Arizona
# 9       Thu   8     11  2018   9:00  MSHSL Girls' State Volleyball Tournament
# 10      Thu  13     12  2018   7:00                Minnesota Wild vs. Florida
# 11      Sun  16     12  2018   5:30                       Wild About Children
# 12      Thu   6     12  2018   7:00                             Disney On Ice
# 13      Tue  11     12  2018   7:00               Minnesota Wild vs. Montreal
# 14      Wed  12     12  2018   7:30        Bob Seger & The Silver Bullet Band
# 15      Mon  31     12  2018   5:00             Minnesota Wild vs. Pittsburgh
# 16      Tue  18     12  2018   7:00               Minnesota Wild vs. San Jose
# 17      Sat  15     12  2018  12:30                Minnesota Wild vs. Calgary
# 18      Sat  29     12  2018   3:00                  Trans-Siberian Orchestra
# 19      Sat  22     12  2018   7:00                 Minnesota Wild vs. Dallas
# 20      Thu  10      1  2019   7:00               Minnesota Wild vs. Winnipeg
# 21      Tue  15      1  2019   7:00            Minnesota Wild vs. Los Angeles
# 22      Sat   2      2  2019   7:00                Minnesota Wild vs. Chicago
# 23      Sat  12      1  2019   7:00                Minnesota Wild vs. Detroit
# 24      Sat  19      1  2019   8:00               Minnesota Wild vs. Columbus
# 25      Thu  17      1  2019   7:00                Minnesota Wild vs. Anaheim
# 26      Sat   9      2  2019   8:00            Trevor Noah: Loud & Clear Tour
# 27      Fri  25      1  2019   7:30              Cinch World's Toughest Rodeo
# 28      Tue  12      2  2019   7:00               Minnesota Wild vs. Edmonton
# 29      Thu   7      2  2019   7:00           Minnesota Wild vs. Philadelphia
# 30      Fri  15      2  2019   7:30             Minnesota Wild vs. New Jersey
# 31      Tue  19      2  2019   7:00                Minnesota Wild vs. Anaheim
# 32      Fri  15      3  2019   7:00                             Blake Shelton
# 33      Sun  17      2  2019   2:00              Minnesota Wild vs. St. Louis
# 34      Sat  16      3  2019   7:00       Minnesota Wild vs. New York Rangers
# 50  http://www.ticketmaster.com/event/06005543DCC6...
# 51  http://www.ticketmaster.com/event/060054A310EA...
# 52  https://www.ticketmaster.com/event/0600555AECB...
# 53  https://www.ticketmaster.com/event/06005552A71...
#
#                                         More Info URL
# #
# 0   https://www.xcelenergycenter.com/events/detail...
# 1   https://www.xcelenergycenter.com/events/detail...
# 2   https://www.xcelenergycenter.com/events/detail...
# 3   https://www.xcelenergycenter.com/events/detail...
# 4   https://www.xcelenergycenter.com/events/detail...
# 5   https://www.xcelenergycenter.com/events/detail...
# 6   https://www.xcelenergycenter.com/events/detail...
# 7   https://www.xcelenergycenter.com/events/detail...
# 8   https://www.xcelenergycenter.com/events/detail...
# 9   https://www.xcelenergycenter.com/events/detail...
# 10  https://www.xcelenergycenter.com/events/detail...
# 11  https://www.xcelenergycenter.com/events/detail...
# 12  https://www.xcelenergycenter.com/events/detail...
# 13  https://www.xcelenergycenter.com/events/detail...
# 14  https://www.xcelenergycenter.com/events/detail...
# 15  https://www.xcelenergycenter.com/events/detail...
# 16  https://www.xcelenergycenter.com/events/detail...
# 17  https://www.xcelenergycenter.com/events/detail...
# 18  https://www.xcelenergycenter.com/events/detail...
# 19  https://www.xcelenergycenter.com/events/detail...
# 20  https://www.xcelenergycenter.com/events/detail...
# 21  https://www.xcelenergycenter.com/events/detail...
# 22  https://www.xcelenergycenter.com/events/detail...
# 23  https://www.xcelenergycenter.com/events/detail...
# 24  https://www.xcelenergycenter.com/events/detail...
# 25  https://www.xcelenergycenter.com/events/detail...
# 26  https://www.xcelenergycenter.com/events/detail...
# 27  https://www.xcelenergycenter.com/events/detail...
# 28  https://www.xcelenergycenter.com/events/detail...
# 29  https://www.xcelenergycenter.com/events/detail...
# 30  https://www.xcelenergycenter.com/events/detail...
# 31  https://www.xcelenergycenter.com/events/detail...
# 32  https://www.xcelenergycenter.com/events/detail...
# 33  https://www.xcelenergycenter.com/events/detail...
# 34  https://www.xcelenergycenter.com/events/detail...
# 35  https://www.xcelenergycenter.com/events/detail...
# 36  https://www.xcelenergycenter.com/events/detail...
# 37  https://www.xcelenergycenter.com/events/detail...
# 38  https://www.xcelenergycenter.com/events/detail...
# 39  https://www.xcelenergycenter.com/events/detail...
# 40  https://www.xcelenergycenter.com/events/detail...
# 41  https://www.xcelenergycenter.com/events/detail...
# 42  https://www.xcelenergycenter.com/events/detail...
# 43  https://www.xcelenergycenter.com/events/detail...
# 44  https://www.xcelenergycenter.com/events/detail...
# 45  https://www.xcelenergycenter.com/events/detail...
# 46  https://www.xcelenergycenter.com/events/detail...
# 47  https://www.xcelenergycenter.com/events/detail...
# 48  https://www.xcelenergycenter.com/events/detail...
# 49  https://www.xcelenergycenter.com/events/detail...
# 50  https://www.xcelenergycenter.com/events/detail...
# 51  https://www.xcelenergycenter.com/events/detail...
# 52  https://www.xcelenergycenter.com/events/detail...
# 53  https://www.xcelenergycenter.com/events/detail...

# %% [markdown]
# # Now to finally convert it to a CSV file

# %%
FINAL_DF.to_csv("Xcel Energy Center Upcoming Events")
